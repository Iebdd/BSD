# %% [markdown]
# # ML Challenge: Customer Outcome Prediction
#
# ## Ziel
# Entwickeln Sie ein Klassifikationsmodell zur Vorhersage von `Target`.
#
# ### Aufgaben
# 1. Daten explorieren
# 2. Missing Values behandeln
# 3. Kategoriale Variablen kodieren
# 4. Mindestens 3 Modelle trainieren (nutzen auch Cross Validation) und base version erstellen
# 5. Accuracy, Precision, Recall und F1 vergleichen
# 6. Hyperparameter Tuning machen und GridCV
# 7. Accuracy, Precision, Recall und F1 vergleichen
# 8. Ergebnisse interpretieren

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# Pfad anpassen, falls notwendig
df = pd.read_csv('kunden.csv')
df.head()
# Out:
#    PersonID  Target ServiceLevel  \
# 0         1       0        Basic
# 1         2       1      Premium
# 2         3       1        Basic
# 3         4       1      Premium
# 4         5       0        Basic
#
#                                             FullName  Gender   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    RelativesOnboard  Dependents         BookingID  PricePaid  Room  \
# 0                 1           0         A/5 21171     7.2500   NaN
# 1                 1           0          PC 17599    71.2833   C85
# 2                 0           0  STON/O2. 3101282     7.9250   NaN
# 3                 1           0            113803    53.1000  C123
# 4                 0           0            373450     8.0500   NaN
#
#   DepartureLocation
# 0                 A
# 1                 B
# 2                 A
# 3                 A
# 4                 A

# %% [markdown]
# ## 1. Exploration

# %%
# TODO: Überblick verschaffen
print(df.shape)
print(df.dtypes)
print(df.isna().sum())
# Out:
# (891, 12)
# PersonID               int64
# Target                 int64
# ServiceLevel          object
# FullName              object
# Gender                object
# Age                  float64
# RelativesOnboard       int64
# Dependents             int64
# BookingID             object
# PricePaid            float64
# Room                  object
# DepartureLocation     object
# dtype: object
# PersonID               0
# Target                 0
# ServiceLevel           0
# FullName               0
# Gender                 0
# Age                  177
# RelativesOnboard       0
# Dependents             0
# BookingID              0
# PricePaid              0
# Room                 687
# DepartureLocation      2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PersonID           891 non-null    int64
#  1   Target             891 non-null    int64
#  2   ServiceLevel       891 non-null    object
#  3   FullName           891 non-null    object
#  4   Gender             891 non-null    object
#  5   Age                714 non-null    float64
#  6   RelativesOnboard   891 non-null    int64
#  7   Dependents         891 non-null    int64
#  8   BookingID          891 non-null    object
#  9   PricePaid          891 non-null    float64
#  10  Room               204 non-null    object
#  11  DepartureLocation  889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#          PersonID      Target         Age  RelativesOnboard  Dependents  \
# count  891.000000  891.000000  714.000000        891.000000  891.000000
# mean   446.000000    0.383838   29.699118          0.523008    0.381594
# std    257.353842    0.486592   14.526497          1.102743    0.806057
# min      1.000000    0.000000    0.420000          0.000000    0.000000
# 25%    223.500000    0.000000   20.125000          0.000000    0.000000
# 50%    446.000000    0.000000   28.000000          0.000000    0.000000
# 75%    668.500000    1.000000   38.000000          1.000000    0.000000
# max    891.000000    1.000000   80.000000          8.000000    6.000000
#
#         PricePaid
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df["Target"].value_counts()
# Out:
# Target
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["DepartureLocation"].value_counts()
# Out:
# DepartureLocation
# A    644
# B    168
# C     77
# Name: count, dtype: int64

# %%
df["RelativesOnboard"].value_counts()
# Out:
# RelativesOnboard
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df["Room"].value_counts()
# Out:
# Room
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df.isnull().sum()
# Out:
# PersonID               0
# Target                 0
# ServiceLevel           0
# FullName               0
# Gender                 0
# Age                  177
# RelativesOnboard       0
# Dependents             0
# BookingID              0
# PricePaid              0
# Room                 687
# DepartureLocation      2
# dtype: int64

# %%
df.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'PersonID'}>,
#         <Axes: title={'center': 'Target'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'RelativesOnboard'}>],
#        [<Axes: title={'center': 'Dependents'}>,
#         <Axes: title={'center': 'PricePaid'}>]], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# Beim Explorieren haben wir festegestellt, dass es einige Features gibt die wir umwandeln oder sogar entfernen müssen. PersonID, Room, BookingID und Fullname werden wir entfernen weil es hier entweder viele fehlende Werte gibt oder die Werte sehr unterschiedlich sind, sodass keine Muster erlernt werden können.

# %% [markdown]
# ## 2. Features und Target definieren

# %%
df["Age"] = df["Age"].fillna(
    df.groupby("Gender")["Age"].transform("median")
)

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["DepartureLocation"] = df["DepartureLocation"].fillna(
    df["DepartureLocation"].mode()[0]
)

# %%
df["DepartureLocation"].isnull().sum()
# Out:
# np.int64(0)

# %%
ids = df["PersonID"]

# %%
df = df.drop(["PersonID", "FullName", "BookingID", "Room"], axis=1)

# %%
df.head()
# Out:
#    Target ServiceLevel  Gender   Age  RelativesOnboard  Dependents  PricePaid  \
# 0       0        Basic    male  22.0                 1           0     7.2500
# 1       1      Premium  female  38.0                 1           0    71.2833
# 2       1        Basic  female  26.0                 0           0     7.9250
# 3       1      Premium  female  35.0                 1           0    53.1000
# 4       0        Basic    male  35.0                 0           0     8.0500
#
#   DepartureLocation
# 0                 A
# 1                 B
# 2                 A
# 3                 A
# 4                 A

# %%
df["RelativesBool"] = df["RelativesOnboard"] >= 1

# %%
df.head()
# Out:
#    Target ServiceLevel  Gender   Age  RelativesOnboard  Dependents  PricePaid  \
# 0       0        Basic    male  22.0                 1           0     7.2500
# 1       1      Premium  female  38.0                 1           0    71.2833
# 2       1        Basic  female  26.0                 0           0     7.9250
# 3       1      Premium  female  35.0                 1           0    53.1000
# 4       0        Basic    male  35.0                 0           0     8.0500
#
#   DepartureLocation  RelativesBool
# 0                 A           True
# 1                 B           True
# 2                 A          False
# 3                 A           True
# 4                 A          False

# %%
df["OneDependents"] = df["Dependents"] == 1
df["TwoOrMoreDependents"] = df["Dependents"] > 1

# %%
df.head()
# Out:
#    Target ServiceLevel  Gender   Age  RelativesOnboard  Dependents  PricePaid  \
# 0       0        Basic    male  22.0                 1           0     7.2500
# 1       1      Premium  female  38.0                 1           0    71.2833
# 2       1        Basic  female  26.0                 0           0     7.9250
# 3       1      Premium  female  35.0                 1           0    53.1000
# 4       0        Basic    male  35.0                 0           0     8.0500
#
#   DepartureLocation  RelativesBool  OneDependents  TwoOrMoreDependents
# 0                 A           True          False                False
# 1                 B           True          False                False
# 2                 A          False          False                False
# 3                 A           True          False                False
# 4                 A          False          False                False

# %%
df = df.drop(["RelativesOnboard", "Dependents"], axis=1)

# %%
df = pd.get_dummies(df, columns=["ServiceLevel", "Gender", "DepartureLocation"], drop_first=True)

# %%
df.head()
# Out:
#    Target   Age  PricePaid  RelativesBool  OneDependents  TwoOrMoreDependents  \
# 0       0  22.0     7.2500           True          False                False
# 1       1  38.0    71.2833           True          False                False
# 2       1  26.0     7.9250          False          False                False
# 3       1  35.0    53.1000           True          False                False
# 4       0  35.0     8.0500          False          False                False
#
#    ServiceLevel_Premium  ServiceLevel_Standard  Gender_male  \
# 0                 False                  False         True
# 1                  True                  False        False
# 2                 False                  False        False
# 3                  True                  False        False
# 4                 False                  False         True
#
#    DepartureLocation_B  DepartureLocation_C
# 0                False                False
# 1                 True                False
# 2                False                False
# 3                False                False
# 4                False                False

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[["Age", "PricePaid"]] = scaler.fit_transform(
    df[["Age", "PricePaid"]]
)

# %%
df.head()
# Out:
#    Target       Age  PricePaid  RelativesBool  OneDependents  \
# 0       0  0.271174   0.014151           True          False
# 1       1  0.472229   0.139136           True          False
# 2       1  0.321438   0.015469          False          False
# 3       1  0.434531   0.103644           True          False
# 4       0  0.434531   0.015713          False          False
#
#    TwoOrMoreDependents  ServiceLevel_Premium  ServiceLevel_Standard  \
# 0                False                 False                  False
# 1                False                  True                  False
# 2                False                 False                  False
# 3                False                  True                  False
# 4                False                 False                  False
#
#    Gender_male  DepartureLocation_B  DepartureLocation_C
# 0         True                False                False
# 1        False                 True                False
# 2        False                False                False
# 3        False                False                False
# 4         True                False                False

# %% [markdown]
# 1. fehlende Werte aus Age anhand des median der Geschlechter
# 2. fehlende Werte für DepartureLocation aufgefüllt mit mode
# 3. Irrelevante Spalten gelöscht (PersonID, FullName, BookingID, Room) weil entweder viele leere Werte oder Werte ohne aussagekraft
# 4. neues Feature für Relatives. Get_Dummies wurde hier nicht benutzt da die genaue Anzahl wie viele Relatives es gibt nicht aussagekräftig für uns war. Daher nur true/false
# 5. zwei neue Features für Dependents wobei noDependents aus OneDpendents und TwoOrMoreDependents abgeleitet werden kann.
# 6. ServiceLevel, Gender, DepartureLocation mit Get_Dummies in Kategorien gespalten
# 7. Age und PricePaid wurden Normalisiert um zu verhindern dass das Modell falsche Muster aus den größen der Werte lernt

# %% [markdown]
# ## 3. Preprocessing definieren

# %% [markdown]
# ## 4. Modelle trainieren (und verbessern)

# %% [markdown]
# ## 5. Interpretation

# %%
# TODO: Interpretieren Sie die Ergebnisse.
# - Welches Modell ist am besten?
# - Wo sind mögliche Overfitting-Risiken?
# - Welche Features könnten besonders wichtig sein?
